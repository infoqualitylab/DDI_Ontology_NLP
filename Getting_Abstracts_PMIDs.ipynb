# %%
###### INCLUSION CRITERIA ANALYSIS###
####The below code 
#Creators:
#Contributors:
#Last updated: 


#encoding=utf8
import importlib

import urllib.request
from xlrd import open_workbook
from Bio import Entrez
import xml.dom.minidom
import xml.etree.ElementTree as ET
import pandas
import openpyxl

Entrez.email = "lhoang2@illinois.edu"

#Read list of PMIDs from txt file
PMID_list_file = open("/Users/phuong/Downloads/AAAI_PMIDs.txt","r")


#Save results to Excel file
from pandas import DataFrame
PMID_list = []
ArtcileTitle_list = []
Abstract_list = []
PublicationType_list = []
MeSH_list = []

for PMID in PMID_list_file.readlines():
    PMID = PMID.replace("\n","")
    print (PMID)

    #Pass PMIDs to PubMed API to get articles' metadata
    link = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=" + PMID + "&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y"            
    f = urllib.request.urlopen(link)   
    print (link)
    tree = ET.parse(f)
    doc = tree.getroot()    

    for child in doc:
        for step_child in child:
            if step_child.tag == "MedlineCitation":
                article_abstract_list = []
                article_publication_type_list = []
                article_MeSH_list = []
                
                for step_child_level_2 in step_child:
                    if step_child_level_2.tag == "PMID":
                        article_PMID =  step_child_level_2.text
                      
                    if step_child_level_2.tag == "Article":
                        for step_child_level_3 in step_child_level_2:
                            if step_child_level_3.tag == "ArticleTitle":
                                article_title = step_child_level_3.text                         
                            
                            if step_child_level_3.tag == "Abstract":
                                if len(step_child_level_3) >= 1:                                    
                                    for step_child_level_4 in step_child_level_3:
                                        if step_child_level_4.tag == "AbstractText":
                                            article_abstract_list.append(step_child_level_4.text)
                                else:
                                    article_abstract_list.append("None")
                                article_abstract = b" ".join(str(x).encode('utf-8') for x in article_abstract_list)

                            
                            if step_child_level_3.tag == "PublicationTypeList":                                
                                for step_child_level_4 in step_child_level_3:
                                    if step_child_level_4.tag == "PublicationType":
                                        article_publication_type_list.append(step_child_level_4.text)
                                    else:
                                        article_publication_type_list.append("None")
                                                                             
                                article_publication_type = " ;".join(str(x) for x in article_publication_type_list)   
                                                                          
                        PMID_list.append(article_PMID)
                        ArtcileTitle_list.append(article_title)
                        Abstract_list.append(article_abstract)
                        PublicationType_list.append(article_publication_type)
                        
                    if step_child_level_2.tag == "MeshHeadingList":
                        for step_child_level_3 in step_child_level_2:
                            if step_child_level_3.tag == "MeshHeading":
                                for step_child_level_4 in step_child_level_3:
                                    if step_child_level_4.tag == "DescriptorName":
                                        article_MeSH_list.append(step_child_level_4.text)
                                
                                article_MeSH = " ;".join(str(x) for x in article_MeSH_list)  
                        MeSH_list.append(article_MeSH)
                                
                        
# print (len(PMID_list))
# print (len(ArtcileTitle_list)
# print len(Abstract_list)
# print len(PublicationType_list)

df = DataFrame({'PMID': PMID_list , 'Article Title': ArtcileTitle_list, 'Abstract': Abstract_list, 
                'Publication Type': PublicationType_list, "MeSH Terms": MeSH_list})
df = df[['PMID','Article Title', 'Abstract', 'Publication Type', 'MeSH Terms']]

df.to_excel('/Users/phuong/Downloads/AAAI_PMIDs_MetaData.xlsx', sheet_name='sheet1', index=False)
# Out:
# 8646822
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=15903129&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 12920410
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=12920410&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 14551182
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=14551182&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 10192752
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=10192752&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 20012601
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=20012601&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 21443601
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=21443601&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 11709322
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=11709322&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 11873000
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=11873000&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 19444001
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=19444001&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 8243504
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=8243504&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 6152055
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=6152055&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 15601809
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=15601809&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 9378846
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=9378846&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 8157044
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=8157044&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 16680561
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=16680561&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 6861848
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=6861848&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 12235455
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=12235455&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 10890312
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=10890312&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 11452243
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=11452243&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 7690693
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=7690693&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 14747427
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=14747427&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 15496643
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=15496643&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 11147928
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=11147928&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 2007317
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=2007317&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 18094219
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=18094219&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 11583471
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=11583471&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 9549635
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=9549635&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 16638740
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=16638740&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 12544511
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=12544511&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 16328318
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=16328318&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 16920892
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=16920892&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 11372588
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=11372588&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 17244765
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=17244765&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 16172184
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=16172184&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 19242403
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=19242403&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 12723462
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=12723462&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 9542477
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=9542477&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 11075313
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=11075313&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 8408732
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=8408732&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 10771449
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=10771449&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 10771448
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=10771448&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 17460607
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=17460607&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 17108811
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=17108811&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 21712498
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=21712498&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 9366029
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=9366029&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 8689810
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=8689810&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 17124578
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=17124578&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 9728893
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=9728893&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 3932079
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=3932079&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 8941024
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=8941024&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 17461702
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=17461702&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 16120067
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=16120067&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 12682802
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=12682802&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 12451430
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=12451430&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 8841155
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=8841155&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 11910267
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=11910267&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 3792426
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=3792426&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 21765368
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=21765368&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 9987702
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=9987702&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 12911366
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=12911366&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 19001559
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=19001559&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 10771458
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=10771458&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 16027406
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=16027406&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 19585395
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=19585395&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 8623953
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=8623953&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 9602962
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=9602962&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 9797793
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=9797793&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 10741630
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=10741630&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 19552747
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=19552747&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 3428348
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=3428348&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 18832427
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=18832427&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 10771455
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=10771455&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 18520598
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=18520598&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 11910256
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=11910256&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 8632299
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=8632299&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# 8801057
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=8801057&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-51f02606ab66> in <module>
#      99
#     100 df = DataFrame({'PMID': PMID_list , 'Article Title': ArtcileTitle_list, 'Abstract': Abstract_list,
# --> 101                 'Publication Type': PublicationType_list, "MeSH Terms": MeSH_list})
#     102 df = df[['PMID','Article Title', 'Abstract', 'Publication Type', 'MeSH Terms']]
#     103
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7354     # figure out the index, if necessary
#    7355     if index is None:
# -> 7356         index = extract_index(arrays)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in extract_index(data)
#    7400             lengths = list(set(raw_lengths))
#    7401             if len(lengths) > 1:
# -> 7402                 raise ValueError('arrays must all be same length')
#    7403
#    7404             if have_dicts:
#
# ValueError: arrays must all be same length
